# %% [markdown]
# # ArogyaVani — Voice Query Backend
#
# Cleaned from `AroygaAI2.ipynb`. This notebook keeps the Gemini + Sarvam voice pipeline only. The deployable server is `main.py`.

# %%
# Install locally/Colab if needed
# !pip -q install -U sarvamai google-genai fastapi uvicorn python-multipart python-dotenv

# %% [markdown]
# ## Pipeline
# `audio → Saaras STT → translation → safety router → Gemini → translation → Bulbul TTS`

# %%
# The complete production implementation is in main.py.
# Run it with:
# uvicorn main:app --host 0.0.0.0 --port 8000

# %% [markdown]
# ### Production endpoint
# `POST /voice-query` with multipart field `file` containing audio.
#
# The API returns the transcript, detected language, translated/generated answer, and base64 WAV audio.
#
# **No RAG. No text-query endpoint. No Colab microphone recording.**
